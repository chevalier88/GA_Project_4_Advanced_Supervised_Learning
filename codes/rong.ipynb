# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#read in dataset
train = pd.read_csv('./assets/train.csv')
weather = pd.read_csv('./assets/weather.csv')
spray = pd.read_csv('./assets/spray.csv')

# %%
# show all rows and columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
train.head(10)
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 5  2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 6  2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 7  2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 8  2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 9  2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# ...

# %%
weather.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#   Sunrise Sunset CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 0    0448   1849             0      M      0.0        0.00       29.10
# 1       -      -             M      M        M        0.00       29.18
# 2    0447   1850      BR     0      M      0.0        0.00       29.38
# 3       -      -   BR HZ     M      M        M        0.00       29.44
# 4    0446   1851             0      M      0.0        0.00       29.39
#
#   SeaLevel  ResultSpeed  ResultDir AvgSpeed
# ...

# %%
spray.head(20)
# Out:
#           Date        Time   Latitude  Longitude
# 0   2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1   2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2   2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3   2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4   2011-08-29  6:57:38 PM  42.390410 -88.088858
# 5   2011-08-29  6:57:48 PM  42.390395 -88.088315
# 6   2011-08-29  6:57:58 PM  42.390673 -88.088002
# 7   2011-08-29  6:58:08 PM  42.391027 -88.088002
# 8   2011-08-29  6:58:18 PM  42.391403 -88.088003
# 9   2011-08-29  6:58:28 PM  42.391718 -88.087995
# 10  2011-08-29  6:58:38 PM  42.392038 -88.087988
# 11  2011-08-29  6:58:48 PM  42.392410 -88.088078
# 12  2011-08-29  6:58:58 PM  42.392800 -88.088332
# 13  2011-08-29  6:59:08 PM  42.393257 -88.088370
# 14  2011-08-29  6:59:18 PM  42.393600 -88.088232
# 15  2011-08-29  7:00:08 PM  42.393203 -88.088417
# 16  2011-08-29  7:00:18 PM  42.392792 -88.088312
# 17  2011-08-29  7:00:28 PM  42.392477 -88.088210
# ...

# %%
train.describe()
# Out:
#               Block      Latitude     Longitude  AddressAccuracy  \
# count  10506.000000  10506.000000  10506.000000     10506.000000
# mean      35.687797     41.841139    -87.699908         7.819532
# std       24.339468      0.112742      0.096514         1.452921
# min       10.000000     41.644612    -87.930995         3.000000
# 25%       12.000000     41.732984    -87.760070         8.000000
# 50%       33.000000     41.846283    -87.694991         8.000000
# 75%       52.000000     41.954690    -87.627796         9.000000
# max       98.000000     42.017430    -87.531635         9.000000
#
#        NumMosquitos    WnvPresent
# count  10506.000000  10506.000000
# mean      12.853512      0.052446
# std       16.133816      0.222936
# min        1.000000      0.000000
# 25%        2.000000      0.000000
# 50%        5.000000      0.000000
# 75%       17.000000      0.000000
# max       50.000000      1.000000

# %%
len(train.Latitude.unique())
# Out:
# 138

# %%
#review data (train)
train.describe(exclude=np.number).T
# Out:
#                         count unique  \
# Date                    10506     95
# Address                 10506    138
# Species                 10506      7
# Street                  10506    128
# Trap                    10506    136
# AddressNumberAndStreet  10506    138
#
#                                                                       top  \
# Date                                                           2007-08-01
# Address                 ORD Terminal 5, O'Hare International Airport, ...
# Species                                            CULEX PIPIENS/RESTUANS
# Street                                                    W OHARE AIRPORT
# Trap                                                                 T900
# AddressNumberAndStreet                 1000  W OHARE AIRPORT, Chicago, IL
#
#                         freq
# Date                     551
# Address                  750
# Species                 4752
# Street                   750
# ...

# %%
train.WnvPresent.value_counts()
# Out:
# 0    9190
# 1     503
# Name: WnvPresent, dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9693 entries, 0 to 10505
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    9693 non-null   object
#  1   Address                 9693 non-null   object
#  2   Species                 9693 non-null   object
#  3   Block                   9693 non-null   int64
#  4   Street                  9693 non-null   object
#  5   Trap                    9693 non-null   object
#  6   AddressNumberAndStreet  9693 non-null   object
#  7   Latitude                9693 non-null   float64
#  8   Longitude               9693 non-null   float64
#  9   AddressAccuracy         9693 non-null   int64
#  10  NumMosquitos            9693 non-null   int64
#  11  WnvPresent              9693 non-null   int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 984.4+ KB

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      2944 non-null   int64
#  1   Date         2944 non-null   object
#  2   Tmax         2944 non-null   int64
#  3   Tmin         2944 non-null   int64
#  4   Tavg         2944 non-null   object
#  5   Depart       2944 non-null   object
#  6   DewPoint     2944 non-null   int64
#  7   WetBulb      2944 non-null   object
#  8   Heat         2944 non-null   object
#  9   Cool         2944 non-null   object
#  10  Sunrise      2944 non-null   object
#  11  Sunset       2944 non-null   object
#  12  CodeSum      2944 non-null   object
#  13  Depth        2944 non-null   object
#  14  Water1       2944 non-null   object
#  15  SnowFall     2944 non-null   object
#  16  PrecipTotal  2944 non-null   object
#  17  StnPressure  2944 non-null   object
# ...

# %%
spray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14294 entries, 0 to 14834
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       14294 non-null  object
#  1   Time       13710 non-null  object
#  2   Latitude   14294 non-null  float64
#  3   Longitude  14294 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 558.4+ KB

# %%
spray[spray['Time'].isnull()]
# Out:
#             Date Time   Latitude  Longitude
# 1030  2011-09-07  NaN  41.987092 -87.794286
# 1031  2011-09-07  NaN  41.987620 -87.794382
# 1032  2011-09-07  NaN  41.988004 -87.794574
# 1033  2011-09-07  NaN  41.988292 -87.795486
# 1034  2011-09-07  NaN  41.988100 -87.796014
# 1035  2011-09-07  NaN  41.986372 -87.794862
# 1036  2011-09-07  NaN  41.986228 -87.795582
# 1037  2011-09-07  NaN  41.984836 -87.793998
# 1038  2011-09-07  NaN  41.984836 -87.794670
# 1039  2011-09-07  NaN  41.984884 -87.795198
# 1040  2011-09-07  NaN  41.982820 -87.793182
# 1041  2011-09-07  NaN  41.982772 -87.793950
# 1042  2011-09-07  NaN  41.982772 -87.795006
# 1043  2011-09-07  NaN  41.983444 -87.795246
# 1044  2011-09-07  NaN  41.984068 -87.795438
# 1045  2011-09-07  NaN  41.984596 -87.795534
# 1046  2011-09-07  NaN  41.984980 -87.795630
# 1047  2011-09-07  NaN  41.986708 -87.796110
# 1048  2011-09-07  NaN  41.987524 -87.796302
# 1049  2011-09-07  NaN  41.988820 -87.796638
# ...

# %%
#get columns names (train)
col_names = train.columns
#check if column is unique
for i in col_names:
  print('{} is unique: {}'.format(i, train[i].is_unique))
# Out:
# Date is unique: False
# Address is unique: False
# Species is unique: False
# Block is unique: False
# Street is unique: False
# Trap is unique: False
# AddressNumberAndStreet is unique: False
# Latitude is unique: False
# Longitude is unique: False
# AddressAccuracy is unique: False
# NumMosquitos is unique: False
# WnvPresent is unique: False

# %%
#get columns names (train)
col_names = spray.columns
#check if column is unique
for i in col_names:
  print('{} is unique: {}'.format(i, spray[i].is_unique))
# Out:
# Date is unique: False
# Time is unique: False
# Latitude is unique: False
# Longitude is unique: False

# %%
#get columns names (train)
col_names = weather.columns
#check if column is unique
for i in col_names:
  print('{} is unique: {}'.format(i, weather[i].is_unique))
# Out:
# Station is unique: False
# Date is unique: False
# Tmax is unique: False
# Tmin is unique: False
# Tavg is unique: False
# Depart is unique: False
# DewPoint is unique: False
# WetBulb is unique: False
# Heat is unique: False
# Cool is unique: False
# Sunrise is unique: False
# Sunset is unique: False
# CodeSum is unique: False
# Depth is unique: False
# Water1 is unique: False
# SnowFall is unique: False
# PrecipTotal is unique: False
# StnPressure is unique: False
# SeaLevel is unique: False
# ResultSpeed is unique: False
# ResultDir is unique: False
# AvgSpeed is unique: False

# %%
train[train.duplicated()]
# Out:
#              Date                                            Address  \
# 99     2007-06-26     2200 West 113th Street, Chicago, IL 60643, USA
# 295    2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 351    2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 353    2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 512    2007-07-18  3300 West Randolph Street, Chicago, IL 60612, USA
# 531    2007-07-18        South Stony Island Avenue, Chicago, IL, USA
# 548    2007-07-18          3700 118th Street, Chicago, IL 60617, USA
# 587    2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 588    2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 589    2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 590    2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 591    2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# 593    2007-07-19          3700 118th Street, Chicago, IL 60617, USA
# ...

# %%
train.duplicated().sum()
# Out:
# 813

# %%
weather.duplicated().sum()
# Out:
# 0

# %%
spray.duplicated().sum()
# Out:
# 541

# %%
spray[spray.duplicated()]
# Out:
#             Date        Time   Latitude  Longitude
# 485   2011-09-07  7:43:40 PM  41.983917 -87.793088
# 490   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 491   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 492   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 493   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 494   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 495   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 496   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 497   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 498   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 499   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 500   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 501   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 502   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 503   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 504   2011-09-07  7:44:32 PM  41.986460 -87.794225
# 505   2011-09-07  7:44:32 PM  41.986460 -87.794225
# ...

# %%
train.drop_duplicates(inplace=True)
spray.drop_duplicates(inplace=True)

# %%
t_spray = pd.merge(train, spray,  how='left', left_on=['Date', 'Latitude', 'Longitude'], right_on= ['Date', 'Latitude', 'Longitude'])

# %%
train.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# ...

# %%
spray.head()
# Out:
#          Date        Time   Latitude  Longitude
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858

# %%
t_spray.tail(50)
# Out:
#             Date                                            Address  \
# 9643  2013-09-26  7100 South South Shore Drive, Chicago, IL 6064...
# 9644  2013-09-26    5000 South Union Avenue, Chicago, IL 60609, USA
# 9645  2013-09-26    5000 South Union Avenue, Chicago, IL 60609, USA
# 9646  2013-09-26  7900 South South Chicago Avenue, Chicago, IL 6...
# 9647  2013-09-26   5200 South Kolmar Avenue, Chicago, IL 60632, USA
# 9648  2013-09-26   5200 South Kolmar Avenue, Chicago, IL 60632, USA
# 9649  2013-09-26      6300 West 64th Street, Chicago, IL 60638, USA
# 9650  2013-09-26    3700 South Pulaski Road, Chicago, IL 60623, USA
# 9651  2013-09-26                South Doty Avenue, Chicago, IL, USA
# 9652  2013-09-26                South Doty Avenue, Chicago, IL, USA
# 9653  2013-09-26        South Stony Island Avenue, Chicago, IL, USA
# 9654  2013-09-26        South Stony Island Avenue, Chicago, IL, USA
# 9655  2013-09-26       South Brandon Avenue, Chicago, IL 60617, USA
# ...

# %%
t_spray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9693 entries, 0 to 9692
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    9693 non-null   object
#  1   Address                 9693 non-null   object
#  2   Species                 9693 non-null   object
#  3   Block                   9693 non-null   int64
#  4   Street                  9693 non-null   object
#  5   Trap                    9693 non-null   object
#  6   AddressNumberAndStreet  9693 non-null   object
#  7   Latitude                9693 non-null   float64
#  8   Longitude               9693 non-null   float64
#  9   AddressAccuracy         9693 non-null   int64
#  10  NumMosquitos            9693 non-null   int64
#  11  WnvPresent              9693 non-null   int64
#  12  Time                    0 non-null      object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
print (df[columns].value_counts(dropna=False))

# %%
len(train.Latitude.unique())
# Out:
# 138

# %%
len(spray.Latitude.unique())
# Out:
# 12887

# %%
mask = (train['Latitude'] == spray['Latitude'])
